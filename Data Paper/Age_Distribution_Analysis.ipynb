# %%
from google.colab import drive
drive.mount('/content/drive')
CSV_PATH = "/content/drive/MyDrive/dp/data/my/csv/final_xray_metadata.csv"
df = pd.read_csv(CSV_PATH)
overall_age_stats = df['Age_Clean'].describe()
print("Overall Age Statistics:")
print(overall_age_stats)

print("\nAge per Class:")
age_per_class = df.groupby('Class')['Age_Clean'].agg(['mean', 'std', 'min', 'max', 'count']).round(2)
print(age_per_class)

# Histograms
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
classes = sorted(df['Class'].unique())
colors = ['skyblue', 'orange', 'lightgreen']
for i, cls in enumerate(classes):
    class_data = df[df['Class'] == cls]['Age_Clean']
    axes[i].hist(class_data, bins=20, alpha=0.7, color=colors[i])
    axes[i].set_title(f'Age Distribution: {cls}')
    axes[i].set_xlabel('Age (Years)')
    axes[i].set_ylabel('Frequency')

plt.tight_layout()
plt.show()
